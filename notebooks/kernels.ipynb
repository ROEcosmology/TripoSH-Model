# %%
from classy import Class
import numpy as np
from matplotlib import pyplot as plt

# %%
k = np.arange(.005, .3025, .0025)

# %%
a = []
for i in range(1000):
    a.append(np.loadtxt('/home/rneveux/kernels_EFT/pk/z0.61/Omfid.317/full_cosmo/kernels/pk_kernels_'+str(i)+'.txt'))

# %%
for j in range(len(a[0])):
    for i in range(1000):
        plt.plot(k,k*a[i][j])
    plt.show()
